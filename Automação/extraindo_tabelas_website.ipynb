# %%
import pandas as pd

# %%
df = pd.read_html('https://pt.wikipedia.org/wiki/Lista_de_epis%C3%B3dios_de_Os_Simpsons_(temporadas_1%E2%80%9315)')

# %%
len(df)
# Out:
# 17

# %%
df[1]
# Out:
#    Temporada             Episódios               Originalmente exibido  \
#    Temporada Temporada.1 Episódios Episódios.1    Estreia da temporada
# 0        NaN           1        13          13  17 de dezembro de 1989
# 1        NaN           2        22          22   11 de outubro de 1990
# 2        NaN           3        24          24  19 de setembro de 1991
# 3        NaN           4        22          22  24 de setembro de 1992
# 4        NaN           5        22          22  30 de setembro de 1993
# 5        NaN           6        25          25   4 de setembro de 1994
# 6        NaN           7        25          25  17 de setembro de 1995
# 7        NaN           8        25          25   27 de outubro de 1996
# 8        NaN           9        25          25  21 de setembro de 1997
# 9        NaN          10        23          23    23 de agosto de 1998
# 10       NaN          11        22          22  26 de setembro de 1999
# ...
